# %% [markdown]
# ### <center> **End of Semester Exam - Big Data Analytics for Business**
# ##### <center> Masters in Applied Informatics (IT Innovations in Business)
# ##### <center> Ural Federal University, Yekaterinburg, Russian Federation.
# ##### <center> 2022/23 Academic Year
# ----
# ### <center> **Olympics Games (Олимпийские игры)**
#
# # <center> ![](https://png.pngitem.com/pimgs/s/469-4697170_olympic-rings-hd-png-download.png)

# %% [markdown]
# **Name: Maxim Makarov**
#
# **Group №: RIM-120981**
#
# ---

# %% [markdown]
# **Task:** As an analyst, you have been given the task of identifying all kinds of interesting facts about the Olympic Games in the data using the data engineering, analytics and visualization tools.
#
# Use the python notebook to perform your analysis with comments and markdown text also
#
# * Download the data here: https://disk.yandex.ru/d/aJERq9WdoFR5HQ
#
# **Data Description:**
#
# - __ID__ - Уникальный номер атлета (Athlete's unique number)
# - __Name__ - Имя атлета
# - __Sex__ - Пол
# - __Age__ - Возраст
# - __Height__ - Рост (см / cm)
# - __Weight__ - Вес (кг / kg)
# - __Team__ - Название команды
# - __NOC__ - Код Нац.олимп. коммитета (National Olympic Committee 3-letter code)
# - __Games__ - Год и сезон проведения игр (Year and season of games)
# - __Year__ - Год проведения игр
# - __Season__ -сезон проведения игр
# - __City__ - Город проведения игр
# - __Sport__ - Вид спорта
# - __Event__ - Событие
# - __Medal__ - Медаль (Gold, Silver, Bronze, или NA)
#
# -----
#
# **Disclaimer:-** Extra scores will be given for creativity and clarity of analytical results.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('olympic_games.csv', sep = ',') #data import
df1
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# 1                China  CHN  2012 Summer  2012  Summer          London
# 2              Denmark  DEN  1920 Summer  1920  Summer       Antwerpen
# 3       Denmark/Sweden  DEN  1900 Summer  1900  Summer           Paris
# 4          Netherlands  NED  1988 Winter  1988  Winter         Calgary
# ...                ...  ...          ...   ...     ...             ...
# 271111        Poland-1  POL  1976 Winter  1976  Winter       Innsbruck
# 271112          Poland  POL  2014 Winter  2014  Winter           Sochi
# 271113          Poland  POL  2014 Winter  2014  Winter           Sochi
# 271114          Poland  POL  1998 Winter  1998  Winter          Nagano
# 271115          Poland  POL  2002 Winter  2002  Winter  Salt Lake City
#
#                 Sport                                     Event Medal
# 0          Basketball               Basketball Men's Basketball   NaN
# 1                Judo              Judo Men's Extra-Lightweight   NaN
# 2            Football                   Football Men's Football   NaN
# 3          Tug-Of-War               Tug-Of-War Men's Tug-Of-War  Gold
# 4       Speed Skating          Speed Skating Women's 500 metres   NaN
# ...               ...                                       ...   ...
# 271111           Luge                Luge Mixed (Men)'s Doubles   NaN
# 271112    Ski Jumping  Ski Jumping Men's Large Hill, Individual   NaN
# 271113    Ski Jumping        Ski Jumping Men's Large Hill, Team   NaN
# 271114      Bobsleigh                      Bobsleigh Men's Four   NaN
# 271115      Bobsleigh                      Bobsleigh Men's Four   NaN
#
# [271116 rows x 15 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
df1.corr() #data correlations
# Out:
#               ID       Age    Height    Weight      Year
# ID      1.000000 -0.003631 -0.011141 -0.009176  0.011885
# Age    -0.003631  1.000000  0.138246  0.212069 -0.115137
# Height -0.011141  0.138246  1.000000  0.796213  0.047578
# Weight -0.009176  0.212069  0.796213  1.000000  0.019095
# Year    0.011885 -0.115137  0.047578  0.019095  1.000000

# %%
sns.heatmap(df1.corr()); #heat map by correlation
plt.rcParams ['figure.figsize'] = [10, 8] #define plot size for all plots

# %%
df1
df1['Age'].mean(), df1['Age'].median() #Mean and median output
# Out:
# (25.556898357297374, 24.0)

# %%
df1[df1['Age']==26]
# Out:
#             ID                            Name Sex   Age  Height  Weight  \
# 28           9                Antti Sami Aalto   M  26.0   186.0    96.0
# 29          10  Einar Ferdinand "Einari" Aalto   M  26.0     NaN     NaN
# 68          20              Kjetil Andr Aamodt   M  26.0   176.0    85.0
# 69          20              Kjetil Andr Aamodt   M  26.0   176.0    85.0
# 70          20              Kjetil Andr Aamodt   M  26.0   176.0    85.0
# ...        ...                             ...  ..   ...     ...     ...
# 271028  135532            Edward "Eddie" Zwier   M  26.0   176.0    75.0
# 271037  135538                 Jonathan Zwikel   M  26.0   183.0    84.0
# 271050  135546          Sandra Kornelia Zwolle   F  26.0   174.0    65.0
# 271051  135546          Sandra Kornelia Zwolle   F  26.0   174.0    65.0
# 271100  135561                   Frantiek Zyka   M  26.0     NaN     NaN
#
#                   Team  NOC        Games  Year  Season            City  \
# 28             Finland  FIN  2002 Winter  2002  Winter  Salt Lake City
# 29             Finland  FIN  1952 Summer  1952  Summer        Helsinki
# 68              Norway  NOR  1998 Winter  1998  Winter          Nagano
# 69              Norway  NOR  1998 Winter  1998  Winter          Nagano
# 70              Norway  NOR  1998 Winter  1998  Winter          Nagano
# ...                ...  ...          ...   ...     ...             ...
# 271028     Netherlands  NED  1960 Summer  1960  Summer            Roma
# 271037          France  FRA  2002 Winter  2002  Winter  Salt Lake City
# 271050     Netherlands  NED  1998 Winter  1998  Winter          Nagano
# 271051     Netherlands  NED  1998 Winter  1998  Winter          Nagano
# 271100  Czechoslovakia  TCH  1928 Summer  1928  Summer       Amsterdam
#
#                 Sport                                Event Medal
# 28         Ice Hockey          Ice Hockey Men's Ice Hockey   NaN
# 29           Swimming  Swimming Men's 400 metres Freestyle   NaN
# 68      Alpine Skiing         Alpine Skiing Men's Downhill   NaN
# 69      Alpine Skiing          Alpine Skiing Men's Super G   NaN
# 70      Alpine Skiing     Alpine Skiing Men's Giant Slalom   NaN
# ...               ...                                  ...   ...
# 271028         Hockey                  Hockey Men's Hockey   NaN
# 271037     Ice Hockey          Ice Hockey Men's Ice Hockey   NaN
# 271050  Speed Skating     Speed Skating Women's 500 metres   NaN
# 271051  Speed Skating   Speed Skating Women's 1,000 metres   NaN
# 271100      Athletics             Athletics Men's Marathon   NaN
#
# [17675 rows x 15 columns]

# %%
df1["Age"].describe()
# Out:
# count    261642.000000
# mean         25.556898
# std           6.393561
# min          10.000000
# 25%          21.000000
# 50%          24.000000
# 75%          28.000000
# max          97.000000
# Name: Age, dtype: float64

# %%
df1['Age'].plot(kind = 'hist', color='r')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1.loc[(df['Sex']=='F')& (df1['Medal']=='Silver')] #selection of women with silver medals
# Out:
#             ID                                     Name Sex   Age  Height  \
# 163         67  Mariya Vasilyevna Abakumova (-Tarabina)   F  22.0   179.0
# 195         90                Tamila Rashidovna Abasova   F  21.0   163.0
# 286        153                    Monica Cecilia Abbott   F  23.0   191.0
# 311        165                      Nia Nicole Abdallah   F  20.0   175.0
# 677        394                               Irene Abel   F  19.0   160.0
# ...        ...                                      ...  ..   ...     ...
# 270704  135379                   Erika Zuchold (Barth-)   F  25.0   158.0
# 270705  135379                   Erika Zuchold (Barth-)   F  25.0   158.0
# 270939  135489    Anastasiya Valeryevna Zuyeva-Fesikova   F  22.0   182.0
# 271078  135553      Galina Ivanovna Zybina (-Fyodorova)   F  25.0   168.0
# 271103  135563                Olesya Nikolayevna Zykina   F  23.0   171.0
#
#         Weight           Team  NOC        Games  Year  Season       City  \
# 163       80.0         Russia  RUS  2008 Summer  2008  Summer    Beijing
# 195       60.0         Russia  RUS  2004 Summer  2004  Summer     Athina
# 286       88.0  United States  USA  2008 Summer  2008  Summer    Beijing
# 311       56.0  United States  USA  2004 Summer  2004  Summer     Athina
# 677       48.0   East Germany  GDR  1972 Summer  1972  Summer     Munich
# ...        ...            ...  ...          ...   ...     ...        ...
# 270704    48.0   East Germany  GDR  1972 Summer  1972  Summer     Munich
# 270705    48.0   East Germany  GDR  1972 Summer  1972  Summer     Munich
# 270939    71.0         Russia  RUS  2012 Summer  2012  Summer     London
# 271078    80.0   Soviet Union  URS  1956 Summer  1956  Summer  Melbourne
# 271103    64.0         Russia  RUS  2004 Summer  2004  Summer     Athina
#
#              Sport                                   Event   Medal
# 163      Athletics         Athletics Women's Javelin Throw  Silver
# 195        Cycling                  Cycling Women's Sprint  Silver
# 286       Softball               Softball Women's Softball  Silver
# 311      Taekwondo         Taekwondo Women's Featherweight  Silver
# 677     Gymnastics      Gymnastics Women's Team All-Around  Silver
# ...            ...                                     ...     ...
# 270704  Gymnastics          Gymnastics Women's Horse Vault  Silver
# 270705  Gymnastics          Gymnastics Women's Uneven Bars  Silver
# 270939    Swimming  Swimming Women's 200 metres Backstroke  Silver
# 271078   Athletics              Athletics Women's Shot Put  Silver
# 271103   Athletics  Athletics Women's 4 x 400 metres Relay  Silver
#
# [3735 rows x 15 columns]

# %%
df1['Medal'].isna().sum()
# Out:
# 231333

# %%
df2 = df1['Medal'].isna().sum()/len(df1) 
df2
# Out:
# 0.853262072323286

# %%
df1['Medal'].value_counts()
# Out:
# Gold      13372
# Bronze    13295
# Silver    13116
# Name: Medal, dtype: int64

# %%
df1.groupby('Medal')['Sex'].value_counts()
# Out:
# Medal   Sex
# Bronze  M      9524
#         F      3771
# Gold    M      9625
#         F      3747
# Silver  M      9381
#         F      3735
# Name: Sex, dtype: int64

# %%
df1.sort_values(['Height','Name'], ascending=[False,True])
# Out:
#             ID                         Name Sex   Age  Height  Weight  \
# 265040  132627                     Yao Ming   M  20.0   226.0   141.0
# 265041  132627                     Yao Ming   M  23.0   226.0   141.0
# 265042  132627                     Yao Ming   M  27.0   226.0   141.0
# 207373  104059        Arvydas Romas Sabonis   M  23.0   223.0   122.0
# 207374  104059        Arvydas Romas Sabonis   M  27.0   223.0   122.0
# ...        ...                          ...  ..   ...     ...     ...
# 192725   96761  variste Marius Fernand Prat   M  24.0     NaN     NaN
# 42797    22086               velyne Cloupet   F   NaN     NaN     NaN
# 156249   78469              ystein Mellerud   M  25.0     NaN     NaN
# 61345    31417                    zcan Ediz   M  17.0     NaN     NaN
# 61346    31417                    zcan Ediz   M  17.0     NaN     NaN
#
#                 Team  NOC        Games  Year  Season          City  \
# 265040         China  CHN  2000 Summer  2000  Summer        Sydney
# 265041         China  CHN  2004 Summer  2004  Summer        Athina
# 265042         China  CHN  2008 Summer  2008  Summer       Beijing
# 207373  Soviet Union  URS  1988 Summer  1988  Summer         Seoul
# 207374     Lithuania  LTU  1992 Summer  1992  Summer     Barcelona
# ...              ...  ...          ...   ...     ...           ...
# 192725        France  FRA  1928 Winter  1928  Winter  Sankt Moritz
# 42797         France  FRA  1928 Summer  1928  Summer     Amsterdam
# 156249        Norway  NOR  1964 Winter  1964  Winter     Innsbruck
# 61345         Turkey  TUR  1992 Summer  1992  Summer     Barcelona
# 61346         Turkey  TUR  1992 Summer  1992  Summer     Barcelona
#
#                        Sport                                     Event   Medal
# 265040            Basketball               Basketball Men's Basketball     NaN
# 265041            Basketball               Basketball Men's Basketball     NaN
# 265042            Basketball               Basketball Men's Basketball     NaN
# 207373            Basketball               Basketball Men's Basketball    Gold
# 207374            Basketball               Basketball Men's Basketball  Bronze
# ...                      ...                                       ...     ...
# 192725  Cross Country Skiing  Cross Country Skiing Men's 50 kilometres     NaN
# 42797              Athletics               Athletics Women's High Jump     NaN
# 156249            Ice Hockey               Ice Hockey Men's Ice Hockey     NaN
# 61345                Archery                  Archery Men's Individual     NaN
# 61346                Archery                        Archery Men's Team     NaN
#
# [271116 rows x 15 columns]

# %%
df1.sort_values(['Weight','Name'], ascending=[False,True])
# Out:
#             ID                           Name Sex   Age  Height  Weight  \
# 23155    12177              Ricardo Blas, Jr.   M  21.0   183.0   214.0
# 23156    12177              Ricardo Blas, Jr.   M  25.0   183.0   214.0
# 205467  103159              Aytami Ruano Vega   M  27.0   200.0   198.0
# 75031    38075                  Marek Galiski   M  29.0   200.0   190.0
# 237039  118869  Christopher J. "Chris" Taylor   M  22.0   196.0   182.0
# ...        ...                            ...  ..   ...     ...     ...
# 192725   96761    variste Marius Fernand Prat   M  24.0     NaN     NaN
# 42797    22086                 velyne Cloupet   F   NaN     NaN     NaN
# 156249   78469                ystein Mellerud   M  25.0     NaN     NaN
# 61345    31417                      zcan Ediz   M  17.0     NaN     NaN
# 61346    31417                      zcan Ediz   M  17.0     NaN     NaN
#
#                  Team  NOC        Games  Year  Season          City  \
# 23155            Guam  GUM  2008 Summer  2008  Summer       Beijing
# 23156            Guam  GUM  2012 Summer  2012  Summer        London
# 205467          Spain  ESP  2004 Summer  2004  Summer        Athina
# 75031          Poland  POL  1980 Summer  1980  Summer        Moskva
# 237039  United States  USA  1972 Summer  1972  Summer        Munich
# ...               ...  ...          ...   ...     ...           ...
# 192725         France  FRA  1928 Winter  1928  Winter  Sankt Moritz
# 42797          France  FRA  1928 Summer  1928  Summer     Amsterdam
# 156249         Norway  NOR  1964 Winter  1964  Winter     Innsbruck
# 61345          Turkey  TUR  1992 Summer  1992  Summer     Barcelona
# 61346          Turkey  TUR  1992 Summer  1992  Summer     Barcelona
#
#                        Sport                                           Event  \
# 23155                   Judo                          Judo Men's Heavyweight
# 23156                   Judo                          Judo Men's Heavyweight
# 205467                  Judo                          Judo Men's Heavyweight
# 75031              Wrestling  Wrestling Men's Super-Heavyweight, Greco-Roman
# 237039             Wrestling  Wrestling Men's Super-Heavyweight, Greco-Roman
# ...                      ...                                             ...
# 192725  Cross Country Skiing        Cross Country Skiing Men's 50 kilometres
# 42797              Athletics                     Athletics Women's High Jump
# 156249            Ice Hockey                     Ice Hockey Men's Ice Hockey
# 61345                Archery                        Archery Men's Individual
# 61346                Archery                              Archery Men's Team
#
#        Medal
# 23155    NaN
# 23156    NaN
# 205467   NaN
# 75031    NaN
# 237039   NaN
# ...      ...
# 192725   NaN
# 42797    NaN
# 156249   NaN
# 61345    NaN
# 61346    NaN
#
# [271116 rows x 15 columns]

# %%
sns.scatterplot(data=df1, x="Weight", y="Height", color="r");

# %%
df1.groupby('Medal')['Age'].describe() #Statistics of medals issued by age
# Out:
#           count       mean       std   min   25%   50%   75%   max
# Medal
# Bronze  13006.0  25.879210  5.831923  10.0  22.0  25.0  29.0  72.0
# Gold    13224.0  25.901013  5.892887  13.0  22.0  25.0  29.0  64.0
# Silver  12821.0  25.996724  6.017395  11.0  22.0  25.0  29.0  73.0

# %%
df1.groupby(['Year','Sex'])['Age'].agg(['mean']) #Statistics of participant ages by year and gender
# Out:
#                mean
# Year Sex
# 1896 M    23.580645
# 1900 F    29.791667
#      M    29.017825
# 1904 F    50.230769
#      M    26.396450
# ...             ...
# 2012 M    26.615904
# 2014 F    25.334652
#      M    26.447699
# 2016 F    25.572875
#      M    26.737307
#
# [69 rows x 1 columns]

# %%
df1.groupby(['Year','Medal'])['Age'].agg(['mean', 'median'])
# Out:
#                   mean  median
# Year Medal
# 1896 Bronze  22.700000    23.0
#      Gold    23.038462    22.0
#      Silver  23.896552    23.0
# 1900 Bronze  28.838462    26.0
#      Gold    28.178771    26.0
# ...                ...     ...
# 2014 Gold    26.742574    26.0
#      Silver  26.558376    26.0
# 2016 Bronze  26.083926    26.0
#      Gold    26.515789    26.0
#      Silver  26.390840    26.0
#
# [105 rows x 2 columns]

# %%
sns.scatterplot(data=df1, x="Age", y="Medal", color="r");

# %%
df3 = df1.copy (deep = True)

# %%
cnct = pd.concat([df1, df3]) #Concatenation by string

# %%
cnct.shape
# Out:
# (542232, 15)

# %%
df.shape
# Out:
# (271116, 15)

# %%
cnct
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# 1                China  CHN  2012 Summer  2012  Summer          London
# 2              Denmark  DEN  1920 Summer  1920  Summer       Antwerpen
# 3       Denmark/Sweden  DEN  1900 Summer  1900  Summer           Paris
# 4          Netherlands  NED  1988 Winter  1988  Winter         Calgary
# ...                ...  ...          ...   ...     ...             ...
# 271111        Poland-1  POL  1976 Winter  1976  Winter       Innsbruck
# 271112          Poland  POL  2014 Winter  2014  Winter           Sochi
# 271113          Poland  POL  2014 Winter  2014  Winter           Sochi
# 271114          Poland  POL  1998 Winter  1998  Winter          Nagano
# 271115          Poland  POL  2002 Winter  2002  Winter  Salt Lake City
#
#                 Sport                                     Event Medal
# 0          Basketball               Basketball Men's Basketball   NaN
# 1                Judo              Judo Men's Extra-Lightweight   NaN
# 2            Football                   Football Men's Football   NaN
# 3          Tug-Of-War               Tug-Of-War Men's Tug-Of-War  Gold
# 4       Speed Skating          Speed Skating Women's 500 metres   NaN
# ...               ...                                       ...   ...
# 271111           Luge                Luge Mixed (Men)'s Doubles   NaN
# 271112    Ski Jumping  Ski Jumping Men's Large Hill, Individual   NaN
# 271113    Ski Jumping        Ski Jumping Men's Large Hill, Team   NaN
# 271114      Bobsleigh                      Bobsleigh Men's Four   NaN
# 271115      Bobsleigh                      Bobsleigh Men's Four   NaN
#
# [542232 rows x 15 columns]
